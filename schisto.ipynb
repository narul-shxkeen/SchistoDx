# %%
# import ultralytics
from roboflow import Roboflow
from ultralytics import YOLO
import torch

# %%
print(torch.cuda.is_available())
print(torch.cuda.memory_allocated())
# Out:
# True
# 0

# %%
torch.cuda.set_device(0)

# %%
cuda=torch.device('cuda')

# %%
# import os

# os.environ["PYTORCH_NO_CUDA_MEMORY_CACHING"] = "1"
# os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
# !nvidia-smi
# Out:
# Sun Feb  8 02:06:47 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 575.64.05              Driver Version: 575.64.05      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3050 ...    Off |   00000000:01:00.0 Off |                  N/A |
# | N/A   38C    P0             12W /   60W |      15MiB /   4096MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# rf = Roboflow(api_key="n5RYzQdAZttrvpfB6YD0")
# project = rf.workspace("schistosomiases-eggs-labelling").project("schistosomiases-eggs")
# version = project.version(6)
# dataset = version.download("yolov11")
from roboflow import Roboflow
rf = Roboflow(api_key="n5RYzQdAZttrvpfB6YD0")
project = rf.workspace("schistosomiases-eggs-labelling").project("schistosomiases-eggs")
version = project.version(8)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Schistosomiases-Eggs--8 in yolov11:: 100%|██████████| 208/208 [00:00<00:00, 3434.21it/s]

# %%
model = YOLO("yolo11l.pt")  # load a pretrained model (recommended for training)
# Out:
# ...
# 100%|██████████| 49.0M/49.0M [00:04<00:00, 10.5MB/s]

# %%
results = model.train(data="./Schistosomiases-Eggs--8/data.yaml", epochs=200, imgsz=640, batch=2)
# Out:
# New https://pypi.org/project/ultralytics/8.4.12 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.156 🚀 Python-3.13.7 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3768MiB)
# ...

# %%
# Cell for validation with confusion matrix
result = YOLO("./runs/detect/train/weights/best.pt")  # load the best trained model weights

# Validate the model
metrics = result.val()  # validate using the loaded model

# Print metrics
print(f"mAP50-95: {metrics.box.map}")
print(f"mAP50: {metrics.box.map50}")
print(f"mAP75: {metrics.box.map75}")

# Print confusion matrix
print("\nConfusion Matrix:")
print(metrics.confusion_matrix.matrix)

# Optionally, plot and save the confusion matrix
metrics.confusion_matrix.plot(save_dir='./runs/detect/train', names=list(metrics.names.values()))
# Out:
# Ultralytics 8.3.156 🚀 Python-3.13.7 torch-2.7.1+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3768MiB)
# YOLO11l summary (fused): 190 layers, 25,280,083 parameters, 0 gradients, 86.6 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 614.1±861.8 MB/s, size: 85.4 KB)
# val: Scanning /home/vshokeen/Programming/RBH_2026/Yolo/scripts/Schistosomiases-Eggs--8/valid/labels.cache... 17 images, 9 backgrounds, 0 corrupt: 100%|██████████| 17/17 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.27s/it]
#                    all         17        429      0.876      0.837      0.881       0.42
# Speed: 6.4ms preprocess, 110.1ms inference, 0.0ms loss, 4.2ms postprocess per image
# Results saved to runs/detect/val
# mAP50-95: 0.4198124725963107
# mAP50: 0.8813105982137314
# mAP75: 0.30572386392156203
#
# Confusion Matrix:
# [[        373          69]
#  [         56           0]]
# ...
